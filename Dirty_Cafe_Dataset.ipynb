# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Harsh\Downloads\dirty_cafe_sales.csv")
df.head(20)
# Out:
#    transaction_id      item quantity price_per_unit  total_spent   \
# 0     TXN_1961373    Coffee        2               2            4
# 1     TXN_4977031      Cake        4               3           12
# 2     TXN_4271903    Cookie        4               1       ERROR
# 3     TXN_7034554     Salad        2               5           10
# 4     TXN_3160411    Coffee        2               2            4
# 5     TXN_2602893  Smoothie        5               4           20
# 6     TXN_4433211   UNKNOWN        3               3            9
# 7     TXN_6699534  Sandwich        4               4           16
# 8     TXN_4717867       NaN        5               3           15
# 9     TXN_2064365  Sandwich        5               4           20
# 10    TXN_2548360     Salad        5               5           25
# 11    TXN_3051279  Sandwich        2               4            8
# 12    TXN_7619095  Sandwich        2               4            8
# 13    TXN_9437049    Cookie        5               1            5
# 14    TXN_8915701     ERROR        2             1.5            3
# 15    TXN_2847255     Salad        3               5           15
# 16    TXN_3765707  Sandwich        1               4            4
# 17    TXN_6769710     Juice        2               3            6
# 18    TXN_8876618      Cake        5               3           15
# 19    TXN_3709394     Juice        4               3           12
#
#     payment_method  location transaction_date
# 0      Credit Card  Takeaway       08-09-2023
# 1             Cash  In-store       16-05-2023
# 2      Credit Card  In-store       19-07-2023
# 3          UNKNOWN   UNKNOWN       27-04-2023
# 4   Digital Wallet  In-store       11-06-2023
# 5      Credit Card       NaN       31-03-2023
# 6            ERROR  Takeaway       06-10-2023
# 7             Cash   UNKNOWN       28-10-2023
# 8              NaN  Takeaway       28-07-2023
# 9              NaN  In-store       31-12-2023
# 10            Cash  Takeaway       07-11-2023
# 11     Credit Card  Takeaway            ERROR
# 12            Cash  In-store       03-05-2023
# 13             NaN  Takeaway       01-06-2023
# 14             NaN  In-store       21-03-2023
# 15     Credit Card  In-store       15-11-2023
# 16             NaN       NaN       10-06-2023
# 17            Cash  In-store       24-02-2023
# 18            Cash     ERROR       25-03-2023
# 19            Cash  Takeaway       15-01-2023

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    10000 non-null  object
#  1   item              9667 non-null   object
#  2   quantity          9862 non-null   object
#  3   price_per_unit    9821 non-null   object
#  4   total_spent       9827 non-null   object
#  5   payment_method    7421 non-null   object
#  6   location          6735 non-null   object
#  7   transaction_date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %% [markdown]
# ### We will strip the space from columns and each rows

# %%
df = df.apply(lambda x : x.str.strip())
df.columns = df.columns.str.strip()

# %%
df.item.unique() # different values are 'UNKNOWN' and 'ERROR'
# Out:
# array(['Coffee', 'Cake', 'Cookie', 'Salad', 'Smoothie', 'UNKNOWN',
#        'Sandwich', nan, 'ERROR', 'Juice', 'Tea'], dtype=object)

# %% [markdown]
# ### Replce 'UNKNOWN' and 'ERROR' with null

# %%
df.replace(['UNKNOWN', 'ERROR', np.nan], pd.NA, inplace = True)

# %%
df.isna().sum()
# Out:
# transaction_id         0
# item                 969
# quantity             479
# price_per_unit       533
# total_spent          502
# payment_method      3178
# location            3961
# transaction_date     460
# dtype: int64

# %% [markdown]
# ### Let's change the data typs

# %%
df[['quantity', 'price_per_unit', 'total_spent']] = df[['quantity', 'price_per_unit', 'total_spent']].apply(pd.to_numeric, errors = 'coerce')
df['transaction_date'] = pd.to_datetime(df['transaction_date'], errors = 'coerce', format = '%d-%m-%Y')

# %%
df.dtypes
# Out:
# transaction_id              object
# item                        object
# quantity                   float64
# price_per_unit             float64
# total_spent                float64
# payment_method              object
# location                    object
# transaction_date    datetime64[ns]
# dtype: object

# %% [markdown]
# ### Let's fill the price_per_unit

# %%
df[['item', 'price_per_unit']].drop_duplicates()
df.groupby('item')['price_per_unit'].median()
# Out:
# item
# Cake        3.0
# Coffee      2.0
# Cookie      1.0
# Juice       3.0
# Salad       5.0
# Sandwich    4.0
# Smoothie    4.0
# Tea         1.5
# Name: price_per_unit, dtype: float64

# %%
product = [
    (df['item'] == 'Coffee') & df['price_per_unit'].isna(),
    (df['item'] == 'Cookie') & df['price_per_unit'].isna(),
    (df['item'] == 'Salad') & df['price_per_unit'].isna(),
    (df['item'] == 'Tea') & df['price_per_unit'].isna(),
    (df['item'] == 'Cake') & df['price_per_unit'].isna(),
    (df['item'] == 'Juice') & df['price_per_unit'].isna(),
    (df['item'] == 'Sandwich') & df['price_per_unit'].isna(),
    (df['item'] == 'Smoothie') & df['price_per_unit'].isna(),
]
value = (2, 1, 5, 1.5, 3, 3, 4,4)

df['price_per_unit'] = np.select(product, value, default = df['price_per_unit'])

# %%
mask = (
    df['quantity'].notna() &
    df['total_spent'].notna() &
    df['price_per_unit'].isna()
)

df.loc[mask, 'price_per_unit'] = df.loc[mask, 'total_spent'] / df.loc[mask, 'quantity']

# %%
df['price_per_unit'].isna().sum()
# Out:
# np.int64(6)

# %% [markdown]
# ### Let's fill the quantity and total spent columns

# %%
mask = (
    df['quantity'].isna() &
    df['total_spent'].notna() &
    df['price_per_unit'].notna()
)

df.loc[mask, 'quantity'] = (df.loc[mask, 'total_spent'] / df.loc[mask, 'price_per_unit'])

mask = (
    df['quantity'].notna() &
    df['total_spent'].isna() &
    df['price_per_unit'].notna()
)

df.loc[mask, 'total_spent'] = (df.loc[mask, 'price_per_unit'] * df.loc[mask, 'quantity'])

# %%
df['quantity'].isna().sum()
# Out:
# np.int64(23)

# %%
df[df['quantity'].isna()]
# Out:
#      transaction_id      item  quantity  price_per_unit  total_spent  \
# 236     TXN_8562645     Salad       NaN             5.0          NaN
# 278     TXN_3229409     Juice       NaN             3.0          NaN
# 641     TXN_2962976     Juice       NaN             3.0          NaN
# 738     TXN_8696094  Sandwich       NaN             4.0          NaN
# 2796    TXN_9188692      Cake       NaN             3.0          NaN
# 3203    TXN_4565754  Smoothie       NaN             4.0          NaN
# 3224    TXN_6297232    Coffee       NaN             2.0          NaN
# 3401    TXN_3251829       Tea       NaN             1.5          NaN
# 3779    TXN_7376255      <NA>       NaN             NaN         25.0
# 4257    TXN_6470865    Coffee       NaN             2.0          NaN
# 5841    TXN_5884081    Cookie       NaN             1.0          NaN
# 7029    TXN_4628338    Coffee       NaN             2.0          NaN
# 7297    TXN_9944500  Smoothie       NaN             4.0          NaN
# 7597    TXN_1082717      <NA>       NaN             NaN          9.0
# 8021    TXN_2428781     Salad       NaN             5.0          NaN
# 8443    TXN_2023651  Sandwich       NaN             4.0          NaN
# 8465    TXN_9669616    Coffee       NaN             2.0          NaN
# 8479    TXN_1547245  Sandwich       NaN             4.0          NaN
# 8574    TXN_2546684     Juice       NaN             3.0          NaN
# 8732    TXN_4550558    Cookie       NaN             1.0          NaN
# 9590    TXN_9924732  Sandwich       NaN             4.0          NaN
# 9819    TXN_1208561      <NA>       NaN             NaN         20.0
# 9869    TXN_1975184    Coffee       NaN             2.0          NaN
#
#       payment_method  location transaction_date
# 236             <NA>  In-store       2023-05-18
# 278             Cash  Takeaway       2023-04-15
# 641             <NA>      <NA>       2023-03-17
# 738             <NA>  Takeaway       2023-05-14
# 2796     Credit Card      <NA>       2023-12-01
# 3203  Digital Wallet  Takeaway       2023-10-06
# 3224            <NA>      <NA>       2023-04-07
# 3401  Digital Wallet  In-store       2023-07-25
# 3779            <NA>  In-store       2023-05-27
# 4257  Digital Wallet  Takeaway       2023-09-18
# 5841  Digital Wallet  In-store       2023-07-05
# 7029            Cash      <NA>       2023-12-25
# 7297            Cash  In-store       2023-01-03
# 7597  Digital Wallet  In-store       2023-12-13
# 8021            <NA>  In-store       2023-05-09
# 8443            Cash  In-store       2023-05-25
# 8465            <NA>      <NA>       2023-06-03
# 8479            <NA>  Takeaway       2023-09-11
# 8574  Digital Wallet  Takeaway       2023-04-08
# 8732     Credit Card  In-store       2023-08-04
# 9590     Credit Card  In-store       2023-01-18
# 9819     Credit Card      <NA>       2023-08-19
# 9869  Digital Wallet      <NA>       2023-01-15

# %%
item_location_relation = df.pivot_table(
    index = 'item',
    columns = 'location',
    values = 'transaction_id',
    aggfunc = 'count',
    fill_value = 0,
    margins = True,
    margins_name = 'Sum'
)
item_location_relation
# Out:
# location  In-store  Takeaway   Sum
# item
# Cake           321       343   664
# Coffee         318       351   669
# Cookie         332       362   694
# Juice          361       341   702
# Salad          371       343   714
# Sandwich       370       345   715
# Smoothie       322       304   626
# Tea            328       336   664
# Sum           2723      2725  5448

# %%
item_payment_relation = df.pivot_table(
    index = 'item',
    columns = 'payment_method',
    values = 'transaction_id',
    aggfunc = 'count',
    fill_value = 0,
    margins = True,
    margins_name = 'Sum'
)
item_payment_relation
# Out:
# payment_method  Cash  Credit Card  Digital Wallet   Sum
# item
# Cake             276          253             246   775
# Coffee           244          242             265   751
# Cookie           245          253             265   763
# Juice            266          276             285   827
# Salad            285          279             240   804
# Sandwich         253          256             255   764
# Smoothie         236          252             255   743
# Tea              241          232             254   727
# Sum             2046         2043            2065  6154

# %%
#### cake and juice relations
#### cake is more in takeaway and cash, credit_card
#### sandwich and smoothie relations
#### sandwich is more in cash and instore

# %%
df.item.isna().sum()
# Out:
# np.int64(969)

# %%
price = [
    (df['price_per_unit'] == 2 ) & df['item'].isna(),
    (df['price_per_unit'] == 1 ) & df['item'].isna(),
    (df['price_per_unit'] == 5 ) & df['item'].isna(),
    (df['price_per_unit'] == 1.5 ) & df['item'].isna(),
]

items = ('Coffee', 'Cookie', 'Salad', 'Tea',)

df['item'] = np.select(price, items, default = df['item'])

# %%
def infer_item(row):
    # if the item is empty them
    if pd.isna(row['item']):

        price = row['price_per_unit']
        location = row['location']
        payment = row['payment_method']

        # Cake vs Juice
        if price == 3:
            if (
                not pd.isna(location) and
                not pd.isna(payment) and
                location == 'Takeaway' and
                payment in ['Cash', 'Credit Card']
            ):
                return 'Cake'
            else:
                return 'Juice'

        elif price == 4:
            if (
                not pd.isna(location) and
                not pd.isna(payment) and
                location == 'In-store' and
                payment == 'Cash'
            ):
                return 'Sandwich'
            else:
                return 'Smoothie'

        else:
            return 
            

    # if the item is not empty keep the data same
    return row['item']

# %%
df['item'] = df.apply(infer_item, axis = 1)

# %%
df.dropna(subset=['quantity', 'item'], inplace=True)

# %%
df.isna().sum()
# Out:
# transaction_id         0
# item                   0
# quantity               0
# price_per_unit         0
# total_spent            0
# payment_method      3168
# location            3952
# transaction_date     460
# dtype: int64

# %%
df.sort_values(by = 'transaction_id', inplace = True)

# %%
df.head()
# Out:
#      transaction_id      item  quantity  price_per_unit  total_spent  \
# 2987    TXN_1000555       Tea       1.0             1.5          2.0
# 115     TXN_1001832     Salad       2.0             5.0         10.0
# 418     TXN_1002457    Cookie       5.0             1.0          5.0
# 3417    TXN_1003246     Juice       2.0             3.0          6.0
# 4366    TXN_1004184  Smoothie       1.0             4.0          4.0
#
#       payment_method  location transaction_date
# 2987     Credit Card  In-store       2023-10-19
# 115             Cash  Takeaway              NaT
# 418   Digital Wallet  Takeaway       2023-09-29
# 3417            <NA>      <NA>       2023-02-15
# 4366     Credit Card  In-store       2023-05-18

# %% [markdown]
# ### Let's fill the missing values from payment_method, location, transaction_date

# %%
df['transaction_date'] = df['transaction_date'].ffill()

# %%
df.fillna({'payment_method':df['payment_method'].mode()[0],
            'location': df['location'].mode()[0]}, inplace = True)

# %%
df.isna().sum()
# Out:
# transaction_id      0
# item                0
# quantity            0
# price_per_unit      0
# total_spent         0
# payment_method      0
# location            0
# transaction_date    0
# dtype: int64

# %%
df.head(20)
# Out:
#      transaction_id      item  quantity  price_per_unit  total_spent  \
# 2987    TXN_1000555       Tea       1.0             1.5          2.0
# 115     TXN_1001832     Salad       2.0             5.0         10.0
# 418     TXN_1002457    Cookie       5.0             1.0          5.0
# 3417    TXN_1003246     Juice       2.0             3.0          6.0
# 4366    TXN_1004184  Smoothie       1.0             4.0          4.0
# 3995    TXN_1004563       Tea       5.0             1.5          8.0
# 1886    TXN_1005331    Coffee       1.0             2.0          2.0
# 8071    TXN_1005377      Cake       5.0             3.0         15.0
# 9311    TXN_1005472    Coffee       4.0             2.0          8.0
# 4744    TXN_1006942     Salad       1.0             5.0          5.0
# 1498    TXN_1007347     Salad       4.0             5.0         20.0
# 2561    TXN_1009421    Cookie       4.0             1.0          4.0
# 6667    TXN_1010950    Cookie       1.0             1.0          1.0
# 3021    TXN_1011236      Cake       1.0             3.0          3.0
# 8883    TXN_1012349     Juice       4.0             3.0         12.0
# 5007    TXN_1015883    Cookie       4.0             1.0          4.0
# 3646    TXN_1016246    Coffee       1.0             2.0          2.0
# 4951    TXN_1018470     Juice       3.0             3.0          9.0
# 754     TXN_1018880  Smoothie       5.0             4.0         20.0
# 7825    TXN_1020478    Coffee       1.0             2.0          2.0
#
#       payment_method  location transaction_date
# 2987     Credit Card  In-store       2023-10-19
# 115             Cash  Takeaway       2023-10-19
# 418   Digital Wallet  Takeaway       2023-09-29
# 3417  Digital Wallet  Takeaway       2023-02-15
# 4366     Credit Card  In-store       2023-05-18
# 3995     Credit Card  In-store       2023-10-28
# 1886  Digital Wallet  Takeaway       2023-11-04
# 8071  Digital Wallet  Takeaway       2023-06-03
# 9311     Credit Card  Takeaway       2023-04-21
# 4744     Credit Card  In-store       2023-11-30
# 1498  Digital Wallet  In-store       2023-08-28
# 2561            Cash  Takeaway       2023-02-21
# 6667  Digital Wallet  Takeaway       2023-01-07
# 3021            Cash  In-store       2023-02-08
# 8883            Cash  In-store       2023-07-08
# 5007            Cash  In-store       2023-10-16
# 3646  Digital Wallet  Takeaway       2023-01-19
# 4951  Digital Wallet  Takeaway       2023-01-14
# 754   Digital Wallet  Takeaway       2023-07-15
# 7825  Digital Wallet  Takeaway       2023-03-09

# %%
df.tail(10)
# Out:
#      transaction_id      item  quantity  price_per_unit  total_spent  \
# 9141    TXN_9989719  Smoothie       2.0             4.0          8.0
# 1244    TXN_9991225      Cake       5.0             3.0         15.0
# 1961    TXN_9991468     Juice       4.0             3.0         12.0
# 4676    TXN_9992148       Tea       3.0             1.5          5.0
# 2496    TXN_9996195     Juice       5.0             3.0         15.0
# 1389    TXN_9996968  Sandwich       1.0             4.0          4.0
# 7964    TXN_9997263    Cookie       2.0             1.0          2.0
# 4304    TXN_9997620    Cookie       2.0             1.0          2.0
# 98      TXN_9999113     Juice       4.0             3.0         12.0
# 5037    TXN_9999124     Juice       2.0             3.0          6.0
#
#       payment_method  location transaction_date
# 9141     Credit Card  Takeaway       2023-11-26
# 1244     Credit Card  Takeaway       2023-02-03
# 1961     Credit Card  Takeaway       2023-11-30
# 4676            Cash  Takeaway       2023-01-14
# 2496  Digital Wallet  In-store       2023-03-16
# 1389            Cash  In-store       2023-10-14
# 7964  Digital Wallet  Takeaway       2023-03-05
# 4304            Cash  Takeaway       2023-12-11
# 98              Cash  Takeaway       2023-05-27
# 5037  Digital Wallet  Takeaway       2023-05-27

# %%
df.to_csv('Cleaned_Cafe_Dataset.csv', index = False)
